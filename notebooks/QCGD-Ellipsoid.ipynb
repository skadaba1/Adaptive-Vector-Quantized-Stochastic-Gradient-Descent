# %%
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp
import pickle
from multiprocessing import Pool
import random
import itertools
import time
import math
import scipy
from multiprocessing import Process

# %%
class Quantizer():
    def __init__(self, iters, dimC):
        self.iters = iters;
        self.C = None;
        self.EA = None;
        self.Eb = None;
        self.dimC = dimC;
        
    def load(self, grads):
        self.grads = grads;
        self.d = np.shape(grads)[0];
        self.m = np.shape(grads)[1];
        self.betas = np.ones((self.m,));
        self.points = []
        for i in range(self.dimC):
            xn = np.random.normal(0, 1, self.d);
            xn = xn * 1/np.linalg.norm(xn);
            self.points.append(xn);

    def objective(self, C, A):
        #print(np.shape(C), np.shape(A), np.shape(self.grads))
        total = 0;
        for i in range(self.m):
            total += self.betas[i]*np.square(np.linalg.norm(self.grads[:,i] - C@A))/np.square(np.linalg.norm(self.grads[i]))
        return total/self.m
    
    def compute(self, verbose):
        # Compute minimum covering ellipsoid #
        A = cp.Variable((self.d, self.d), PSD=True);
        b = cp.Variable(self.d);
        objective = cp.Minimize(-cp.log_det(A));
        constraints = [A == A.T];
        for i in range(self.m):
            constraints.append(cp.norm(A@self.grads[:,i] + b) <= 1);
        prob = cp.Problem(objective, constraints);
        print("Starting to compute Lowner-John Ellipsoid...")
        opt = prob.solve('SCS', eps=1e-2, max_iters = 50);
        A = A.value if A.value is not None else self.EA;
        b = b.value if b.value is not None else self.Eb;
        w, v = np.linalg.eigh(A);
        print("First solve status = ", prob.status)
        
        self.EA = A;
        self.Eb = b
        prob = None;
        indexes = range(self.dimC)
        pairs = list(itertools.combinations(indexes, 2))
        eijs = [np.zeros((self.dimC)) for i in range(len(pairs))];
        for index, pair in enumerate(pairs):
            eijs[index][pair[0]] = 1;
            eijs[index][pair[1]] = -1;
        
        # compute set C using N discrete points with SDP relaxation#
        R = np.linalg.norm(np.sum(self.grads, 1))
        X = cp.Variable((self.d, self.dimC));
        Y = cp.Variable((self.dimC, self.dimC));
        alpha = cp.Variable(1);
        B = cp.vstack([cp.hstack([np.identity(self.d), X]), cp.hstack([X.T, Y])])
        upper_bound = w[0];
        lower_bound = w[1]/self.dimC;
        constraints = [B >= 0, cp.diff(X, k=1, axis=1) <= R];
        expr = alpha + cp.sum(cp.diff(X, k=1, axis=1));
        for i in range(self.dimC):
            if(i < self.grads.shape[1]):
                expr += cp.norm(X[:,i] - self.grads[:, -i]);
            else:
                expr += cp.norm(X[:,i] - np.linalg.inv(A)@(random.choice(self.points) - b))
            constraints.append(cp.norm(A@X[:,i] + b) <= 1)
        for i in range(len(eijs)):
            constraints.append(- alpha <= eijs[i].T@Y@eijs[i]);
            constraints.append(alpha >= eijs[i].T@Y@eijs[i]);
        objective = cp.Minimize(expr);
        prob = cp.Problem(objective, constraints);
        flag = False;
        try:
            opt = prob.solve('ECOS', eps=1e-2)
        except:
            flag = True
        ## Catch infeasible case ##
        if(prob.status not in ['optimal', 'optimal_inaccurate'] or flag):
            print("Defaulted to border fitting");
            X = cp.Variable((self.d, self.dimC));
            alpha = cp.Variable(1);
            expr = 0; constraints = [];
            for i in range(self.dimC):
                if(i < self.grads.shape[1]):
                    expr += cp.norm(X[:,i] - self.grads[:, -i]);
                else:
                    expr += cp.norm(X[:,i] - np.linalg.inv(A)@(random.choice(self.points) - b))
                constraints.append(cp.norm(A@X[:,i] + b) <= 1 + alpha)
            objective = cp.Minimize(expr);
            prob = cp.Problem(objective, constraints);
            opt = prob.solve('ECOS');
            
        print("Second solve status = ", prob.status)
        self.C = self.C if X.value is None else X.value
        
        return opt
    
    def plot(self, grads):
        A = self.EA;
        b = self.Eb
        r = 1;
        #The lower this value the higher quality the circle is with more points generated
        stepSize = 0.01
        #Generated vertices
        positions = []
        t = 0
        while t < 2 * math.pi:
            positions.append(np.array([r * math.cos(t), r * math.sin(t)]))
            t += stepSize
        ellipsoid_coords_x = []
        ellipsoid_coords_y = []
        for pos in positions:
            point = np.linalg.inv(A)@(pos - b)
            ellipsoid_coords_x.append(point[0]);
            ellipsoid_coords_y.append(point[1]);
        plt.figure(1);
        plt.plot(grads[0,:], grads[1,:], 'b.', label='True grads');
        plt.plot(self.C[0,:], self.C[1,:], 'g.', label='Discrete (bin) points');
        plt.plot(ellipsoid_coords_x, ellipsoid_coords_y, 'r-', label='Parameterized ellipse');
        plt.legend(loc='upper right')
    
    def quantize(self, g):
        val = 0;
        index = 0;
        min_dist = float('inf');
        for i in range(self.dimC):
            dist = np.linalg.norm(self.C[:, i] - g)
            if(dist < min_dist):
                min_dist = dist;
                index = i;
        val = min_dist;
        print("Minimum relative distance = ", min_dist/np.linalg.norm(g));
        return (index, val)

# %%
## Distributed Least Squares Toy Model ##
class AgentLSQ():
    def __init__(self, A, b, nagents, r, dimC, qflag):
        self.A = A
        self.b = b
        self.r = r;
        self.nagents = nagents;
        self.grads = [];
        self.PASS = True;
        iters = 10000;
        self.Q = Quantizer(iters, dimC);
        self.qflag = qflag;
    
    def grad(self, x, flag):
        lmbda = 0.1
        g = self.A.T@self.A@x - self.A.T@self.b + lmbda*2*x
        self.grads.append(np.expand_dims(g, 1));
        ch = -1;
        qh = -1;
        bits = 0;
        if(self.qflag != 0): ## do not run if quantize
            flag = False;
        if(((len(self.grads)-self.r >= 0) or (len(self.grads) >= 2 and self.PASS)) and flag):
            G = np.hstack(self.grads);
            self.Q.load(G);
            start = time.time();
            ch = self.Q.compute(False);
            bits += self.Q.d * self.Q.dimC;
            print("Time to compute C = ", time.time() - start);
            self.grads = [];
            self.PASS = False;
            print("Recomputing C... | Converged with alpha value = ", ch)
        if(self.Q.C is not None and flag):
            bits += self.Q.dimC * (1/16);
            ghat, qh = self.Q.quantize(g) #self.Q.C.shape[1]
            return (self.Q.C[:,ghat], ch, qh, bits)
        else:
            if(self.qflag == 2):
                g = np.sign(g);
            print("Sending full precision gradients")
            bits += len(g)
            return (g, ch, qh, bits)

        
    def objective(self, x):
        return np.square(np.linalg.norm(self.A@x-self.b)) + np.square(np.linalg.norm(x));
    
class DLSQ():
    def __init__(self, m, n, nagents, lr, r, dimC, qflag):
        A = np.random.random((m,n))
        z = np.random.random((n,))
        b = A@z + np.random.random((m))

        print('Computing optimal...');
        self.optimal = np.square(np.linalg.norm(A@np.linalg.inv(A.T@A + 0.1*np.identity(n))@A.T@b-b))
        print('finished! | optimal = ', self.optimal)
        
        self.x = np.zeros((n,));
        self.m = m;
        self.n = n;
        self.r = r;
        self.nagents = nagents;
        self.lr = lr;  
        self.agents = self.distribute(A, b, nagents, r, dimC, qflag);
        
        self.A = A;
        self.b = b;
    
    def split(self, a, n):
        k, m = divmod(len(a), n)
        return (a[i*k+min(i, m):(i+1)*k+min(i+1, m)] for i in range(n))

    def distribute(self, A, b, nagents, r, dimC, qflag):
        agents = [];
        splits = list(self.split(range(self.m), self.nagents))
        
        for sp in splits:
            agents.append(AgentLSQ(A[sp, :], b[sp], self.nagents, r, dimC, qflag));
        return agents;
    
    def computeGradFromLocal(self, x, flag):
        temp = np.zeros((self.n,))
        normalizing = 0;
        total_bits = 0;
        for n in range(self.nagents):
            localgrad, ch, qh, bits = self.agents[n].grad(self.x, flag)
            total_bits += bits;
            temp += localgrad
            normalizing += np.linalg.norm(localgrad)
        
        return (temp/normalizing, ch, qh, total_bits);
    
    def step(self, i, flag):
        g, ch, qh, bits = self.computeGradFromLocal(self.x, flag);
        ak = (self.objective()-self.optimal)/np.square(np.linalg.norm(g));
        xnext = self.x - min(ak, self.lr/np.sqrt(i+1))*g
        self.x = xnext + 0.1*(xnext - self.x);
        return (ch, qh, bits);
    
    def objective(self):
        return np.sum([self.agents[i].objective(self.x) for i in range(self.nagents)])
        
    def run(self, iters, verbose):
        history = [];
        compute_history = [];
        quantize_history = [];
        bit_history = [];
        i = 0;
        run = True;
        while(run and i < iters):
            print("Current objective value = ", np.square(np.linalg.norm(self.A@self.x - self.b)) + np.square(np.linalg.norm(self.x)))
            gap = (self.objective()-self.optimal)/self.optimal
            print("Iteration = " + str(i) + " | Relative Optimality gap = " + str(gap))
            print("")
            if(np.abs(gap) <= 1e-1):
                run = False;
            history.append(gap);
            
            flag = True
            if(i >= self.r):
                flag = (np.diff(history[-3::], 1, 0) >= 0).all()
                flag = not flag
                
            ch, qh, bits = self.step(i, flag);
            bit_history.append(bits);
            if(ch != -1):
                compute_history.append(ch)
            if(qh != -1):
                quantize_history.append(qh);
            i += 1;
        #if(verbose):
        #    plt.yscale('log')
        #    plt.plot(range(i), history);
        return (history, compute_history, quantize_history, bit_history);

# %%
## Execute DLSQ without Quantization ##
def execute(nagents, dimC, r, m=10, n=10, iters=1000, lr=0.1, verbose=False, qflag=0): 
    dlsqexe = DLSQ(m, n, nagents, lr, r, dimC, qflag);
    history, compute_history, quantize_history, bit_history = dlsqexe.run(iters, True)
    comp_ratio = np.sum(bit_history)/(n*nagents*len(history));
    print("Compression ratio achieved = ", comp_ratio);
    print("Optimal = ", dlsqexe.optimal)
    print("")
    print("Done...")
    print("___________________________________________________________________")
    if(verbose):
        plt.figure(1);
        plt.yscale('log');
        plt.plot(range(len(history)), history);
        plt.figure(2);
        plt.yscale('log');
        plt.plot(range(len(compute_history)), compute_history);
        plt.figure(3);
        plt.yscale('log');
        plt.plot(range(len(quantize_history)), quantize_history);
        plt.figure(4);
        plt.yscale('log');
        plt.plot(range(len(bit_history)), bit_history);
    return history, compute_history, quantize_history, bit_history, comp_ratio

# %%
#test = execute(nagents=5, dimC=20, r=50, m=10000, n=50, iters=1000, lr=1.0, verbose=True, qflag=0)

# %%
# No quantization here #
h1, c1, q1, b1, cr1 = execute(nagents=5, dimC=5, r=50, m=10000, n=50, iters=1000, lr=0.1, verbose=False, qflag=1)
h2, c2, q2, b2, cr2 = execute(nagents=5, dimC=5, r=50, m=10000, n=50, iters=1000, lr=0.1, verbose=False, qflag=2)
# Out:
# Computing optimal...
# finished! | optimal =  855.4520848722763
# Current objective value =  1516484.0460292127
# Iteration = 0 | Relative Optimality gap = 1771.7282133582414
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1422182.962498869
# Iteration = 1 | Relative Optimality gap = 1661.492892404839
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1357334.033276828
# Iteration = 2 | Relative Optimality gap = 1585.6863829205504
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1305510.5897899605
# Iteration = 3 | Relative Optimality gap = 1525.1063307149138
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1261447.708529344
# Iteration = 4 | Relative Optimality gap = 1473.5981756857502
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1222679.5692491932
# Iteration = 5 | Relative Optimality gap = 1428.279437487035
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1187819.2977044324
# Iteration = 6 | Relative Optimality gap = 1387.5288958724923
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1155995.9518589487
# Iteration = 7 | Relative Optimality gap = 1350.3284420572418
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1126620.4556527555
# Iteration = 8 | Relative Optimality gap = 1315.989461318292
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1099272.463060923
# Iteration = 9 | Relative Optimality gap = 1284.0205799939383
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1073639.6240996474
# Iteration = 10 | Relative Optimality gap = 1254.056669009974
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1049482.346369001
# Iteration = 11 | Relative Optimality gap = 1225.8176510314838
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1026612.0834400817
# Iteration = 12 | Relative Optimality gap = 1199.0831201471751
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1004877.3009755566
# Iteration = 13 | Relative Optimality gap = 1173.6759366261515
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  984154.0432829931
# Iteration = 14 | Relative Optimality gap = 1149.4511994620223
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  964339.3819217522
# Iteration = 15 | Relative Optimality gap = 1126.2885879633266
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  945346.7384274871
# Iteration = 16 | Relative Optimality gap = 1104.0868941391004
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  927102.4649679159
# Iteration = 17 | Relative Optimality gap = 1082.7600255736781
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  909543.2926988048
# Iteration = 18 | Relative Optimality gap = 1062.2340226206525
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  892614.3930337143
# Iteration = 19 | Relative Optimality gap = 1042.4447920772197
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  876267.8809859145
# Iteration = 20 | Relative Optimality gap = 1023.3363576294886
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  860461.643309762
# Iteration = 21 | Relative Optimality gap = 1004.8594899799817
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  845158.4092467801
# Iteration = 22 | Relative Optimality gap = 986.9706205737745
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  830325.0051847356
# Iteration = 23 | Relative Optimality gap = 969.6309703141878
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  815931.750612762
# Iteration = 24 | Relative Optimality gap = 952.8058434499087
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  801951.9639554144
# Iteration = 25 | Relative Optimality gap = 936.4640499077526
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  131246.94555305655
# Iteration = 142 | Relative Optimality gap = 152.45249730291567
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  128934.02998719108
# Iteration = 143 | Relative Optimality gap = 149.74897497277846
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  126650.2718060819
# Iteration = 144 | Relative Optimality gap = 147.07953687278692
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  124395.3687919695
# Iteration = 145 | Relative Optimality gap = 144.44382971817487
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  122169.02390937656
# Iteration = 146 | Relative Optimality gap = 141.84150628213015
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  119970.94518145655
# Iteration = 147 | Relative Optimality gap = 139.27222525124944
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  117800.84557010693
# Iteration = 148 | Relative Optimality gap = 136.73565108539324
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  115658.44285970634
# Iteration = 149 | Relative Optimality gap = 134.23145388177812
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  113543.45954434387
# Iteration = 150 | Relative Optimality gap = 131.75930924315023
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  111455.62271841183
# Iteration = 151 | Relative Optimality gap = 129.3188981498914
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  109394.66397044112
# Iteration = 152 | Relative Optimality gap = 126.90990683591517
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  107360.31928006097
# Iteration = 153 | Relative Optimality gap = 124.53202666821551
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  105352.32891797242
# Iteration = 154 | Relative Optimality gap = 122.18495402993832
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  103370.43734882741
# Iteration = 155 | Relative Optimality gap = 119.86839020684972
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  101414.39313691139
# Iteration = 156 | Relative Optimality gap = 117.58204127708115
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  99483.94885453013
# Iteration = 157 | Relative Optimality gap = 115.32561800403619
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  97578.86099300721
# Iteration = 158 | Relative Optimality gap = 113.09883573234887
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  95698.88987620092
# Iteration = 159 | Relative Optimality gap = 110.90141428678702
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  93843.7995764539
# Iteration = 160 | Relative Optimality gap = 108.73307787399948
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  92013.35783289181
# Iteration = 161 | Relative Optimality gap = 106.59355498700978
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  90207.33597199178
# Iteration = 162 | Relative Optimality gap = 104.48257831236202
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  88425.50883034244
# Iteration = 163 | Relative Optimality gap = 102.39988463982998
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  86667.65467952288
# Iteration = 164 | Relative Optimality gap = 100.34521477460214
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  84933.55515302898
# Iteration = 165 | Relative Optimality gap = 98.31831345186046
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  83222.99517517895
# Iteration = 166 | Relative Optimality gap = 96.31892925367302
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  81535.76289193265
# Iteration = 167 | Relative Optimality gap = 94.34681452812323
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  79871.64960356172
# Iteration = 168 | Relative Optimality gap = 92.40172531060317
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  78230.44969910978
# Iteration = 169 | Relative Optimality gap = 90.48342124719906
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  76611.96059258426
# Iteration = 170 | Relative Optimality gap = 88.59166552010142
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  75015.98266082424
# Iteration = 171 | Relative Optimality gap = 86.7262247749737
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  73442.31918298958
# Iteration = 172 | Relative Optimality gap = 84.88686905021714
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  71890.77628162029
# Iteration = 173 | Relative Optimality gap = 83.07337170807007
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  70361.16286521452
# Iteration = 174 | Relative Optimality gap = 81.28550936748358
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  68853.29057227886
# Iteration = 175 | Relative Optimality gap = 79.52306183871745
#
# Sending full precision gradients
# ...
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  886.2604161722129
# Iteration = 943 | Relative Optimality gap = 0.1295493095907431
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  885.9481129703594
# Iteration = 944 | Relative Optimality gap = 0.1292103150873436
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  885.7710139622532
# Iteration = 945 | Relative Optimality gap = 0.1289951724504144
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  885.5061793824485
# Iteration = 946 | Relative Optimality gap = 0.12869543369977324
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  885.3022005725192
# Iteration = 947 | Relative Optimality gap = 0.12845940761323366
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  885.0038331268182
# Iteration = 948 | Relative Optimality gap = 0.12813629337312835
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  884.8334149399099
# Iteration = 949 | Relative Optimality gap = 0.12792915463694218
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  884.5764946964599
# Iteration = 950 | Relative Optimality gap = 0.12763885703610411
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  884.3800384480068
# Iteration = 951 | Relative Optimality gap = 0.1274118210236801
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  884.1018379588513
# Iteration = 952 | Relative Optimality gap = 0.1271135616142494
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  883.9299954205516
# Iteration = 953 | Relative Optimality gap = 0.12690331092615278
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  883.6941592368955
# Iteration = 954 | Relative Optimality gap = 0.12663810756390081
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  883.5126344630718
# Iteration = 955 | Relative Optimality gap = 0.12642538668787057
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  883.2303651757094
# Iteration = 956 | Relative Optimality gap = 0.12612401768239806
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  883.0652242772572
# Iteration = 957 | Relative Optimality gap = 0.12592179783825944
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  882.8291695054054
# Iteration = 958 | Relative Optimality gap = 0.12565931826420781
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  882.691813047006
# Iteration = 959 | Relative Optimality gap = 0.12549484764515917
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  882.4193833841708
# Iteration = 960 | Relative Optimality gap = 0.12520516245657284
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  882.2539455545212
# Iteration = 961 | Relative Optimality gap = 0.12500174023275956
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  882.0323637192635
# Iteration = 962 | Relative Optimality gap = 0.12475661495663896
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  881.8940475134274
# Iteration = 963 | Relative Optimality gap = 0.12459031005605728
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  881.6549207072591
# Iteration = 964 | Relative Optimality gap = 0.12433711832833012
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  881.5055612988958
# Iteration = 965 | Relative Optimality gap = 0.12415451332750628
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  881.3153323338269
# Iteration = 966 | Relative Optimality gap = 0.12394117126080974
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  881.1663275455003
# Iteration = 967 | Relative Optimality gap = 0.12376866428900025
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  880.9391314603922
# Iteration = 968 | Relative Optimality gap = 0.12352896537822926
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  880.8204230224859
# Iteration = 969 | Relative Optimality gap = 0.1233793224419145
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  880.5969349223573
# Iteration = 970 | Relative Optimality gap = 0.12314211753754714
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  880.4785039744123
# Iteration = 971 | Relative Optimality gap = 0.12299354577405329
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  880.2579210389622
# Iteration = 972 | Relative Optimality gap = 0.12275484014819639
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  880.1390863755571
# Iteration = 973 | Relative Optimality gap = 0.12260864625518743
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  879.9211866719417
# Iteration = 974 | Relative Optimality gap = 0.12237635547496878
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  879.8213668153265
# Iteration = 975 | Relative Optimality gap = 0.12224825702619954
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  879.6161522064959
# Iteration = 976 | Relative Optimality gap = 0.12203506815035586
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  879.5067410967728
# Iteration = 977 | Relative Optimality gap = 0.12189412162333028
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  879.2998193866495
# Iteration = 978 | Relative Optimality gap = 0.12167528350751104
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  879.2002177729495
# Iteration = 979 | Relative Optimality gap = 0.12154748214355783
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  879.0031654094447
# Iteration = 980 | Relative Optimality gap = 0.12134227053690863
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  878.8976962305353
# Iteration = 981 | Relative Optimality gap = 0.12120606213810399
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  878.7024920686719
# Iteration = 982 | Relative Optimality gap = 0.12100303345301186
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  878.6102646920428
# Iteration = 983 | Relative Optimality gap = 0.12088082887861543
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  878.4128519487618
# Iteration = 984 | Relative Optimality gap = 0.12067514761444352
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  878.3151774011797
# Iteration = 985 | Relative Optimality gap = 0.12054969703553386
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  878.138285655552
# Iteration = 986 | Relative Optimality gap = 0.12036197995352899
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  878.0520896396976
# Iteration = 987 | Relative Optimality gap = 0.12025125667919415
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  877.8582612332856
# Iteration = 988 | Relative Optimality gap = 0.12004980763062076
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  877.7746526895771
# Iteration = 989 | Relative Optimality gap = 0.11993936060916241
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  877.6001668695405
# Iteration = 990 | Relative Optimality gap = 0.119759166871684
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  877.5181034784918
# Iteration = 991 | Relative Optimality gap = 0.11965057963232416
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  877.3387186755202
# Iteration = 992 | Relative Optimality gap = 0.11946367476301002
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  877.2609505327752
# Iteration = 993 | Relative Optimality gap = 0.11936125053358422
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  877.0911155054685
# Iteration = 994 | Relative Optimality gap = 0.11918508224030154
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  877.0148235561555
# Iteration = 995 | Relative Optimality gap = 0.11908443409814465
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  876.8450892052225
# Iteration = 996 | Relative Optimality gap = 0.1189098458890016
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  876.7675254038211
# Iteration = 997 | Relative Optimality gap = 0.11880667500308204
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  876.5993765700835
# Iteration = 998 | Relative Optimality gap = 0.11863395743672049
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  876.5224900376368
# Iteration = 999 | Relative Optimality gap = 0.11853263407355903
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Compression ratio achieved =  1.0
# Optimal =  839.1106648619267
#
# Done...
# ___________________________________________________________________

# %%
#exp1 = execute(nagents=5, dimC=5, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False)
#exp2 = execute(nagents=5, dimC=10, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False)
#exp3 = execute(nagents=5, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False)
print(exp1[4], exp2[4], exp3[4])
plt.yscale("log")
index = 0; #history, compute_history, quantize_history, bit_history, comp_ratio
plt.figure(1)
plt.xlabel("Iteration #");
plt.ylabel("Relative Optimality Gap")
plt.title("Optimality gap vs Iteration, dep. on M (dimension C)")
plt.plot(range(len(exp1[index])), exp1[index], label="M = 5")
plt.plot(range(len(exp2[index])), exp2[index], label="M = 10")
plt.plot(range(len(exp3[index])), exp3[index], label="M = 20")
plt.plot(range(len(h2)), h2, label='2-bit quantization')
plt.plot(range(len(h1)), h1, label='Full precision baseline')
plt.legend()

index = 1; 
plt.figure(2)
plt.title("Convergence of Recompute, dep. on M (dimension C)")
plt.xlabel("Iteration #");
plt.ylabel("Minimum euclidean distance to true gradient")
plt.plot(range(len(exp1[index])), exp1[index], label="M = 5")
plt.plot(range(len(exp2[index])), exp2[index], label="M = 10")
plt.plot(range(len(exp3[index])), exp3[index], label="M = 20")
plt.legend()
# Out:
# 0.123825 0.2379125 0.2562

# %%
## Plot Ellipse for Presentation Figures ##
m, n = 10, 2
A = np.random.random((m,n))
z = np.random.random((n,))
b = A@z + np.random.random((m))
x = np.zeros((n,));
grads = []

r = 20;
iters = r
dimC = 5;
Q = Quantizer(iters, dimC);
ak = 0.01;
for i in range(r):
    g = A.T@A@x - A.T@b;
    x = x - ak*g + np.random.randn(n)
    grads.append(np.expand_dims(g, 1));
G = np.hstack(grads);

Q.load(G)
Q.compute(False)
Q.plot(G)

plt.figure()
G = G.T
hull = scipy.spatial.ConvexHull(G)
import matplotlib.pyplot as plt
plt.plot(G[:,0], G[:,1], 'o')
for simplex in hull.simplices:
    plt.plot(G[simplex, 0], G[simplex, 1], 'k-')
# Out:
# Starting to compute Lowner-John Ellipsoid...
# First solve status =  optimal_inaccurate
# Defaulted to border fitting
# Second solve status =  optimal

# %%
#exp4 = execute(nagents=5, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False)
#exp5 = execute(nagents=10, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False)
#exp6 = execute(nagents=50, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False)
print(exp4[4], exp5[4], exp6[4])
plt.yscale("log")
index = 0; #history, compute_history, quantize_history, bit_history, comp_ratio
plt.figure(1)
plt.xlabel("Iteration #");
plt.ylabel("Relative Optimality Gap")
plt.title("Optimality gap vs Iteration, dep. on # Agents")
plt.plot(range(len(exp4[index])), exp4[index], label="n_agents = 5")
plt.plot(range(len(exp5[index])), exp5[index], label="n_agents = 10")
plt.plot(range(len(exp6[index])), exp6[index], label="n_agents = 50")
plt.plot(range(len(h2)), h2, label='2-bit quantization')
plt.plot(range(len(h1)), h1, label='Full precision baseline')
plt.legend()

index = 1; 
plt.figure(2)
plt.title("Convergence of Recompute, dep. on # Agents")
plt.xlabel("Iteration #");
plt.ylabel("Minimum euclidean distance to true gradient")
plt.plot(range(len(exp4[index])), exp4[index], label="n_agents = 5")
plt.plot(range(len(exp5[index])), exp5[index], label="n_agents = 10")
plt.plot(range(len(exp6[index])), exp6[index], label="n_agents = 50")
plt.legend()
# Out:
# 0.30105 0.2874 0.2913

# %%
#exp7 = execute(nagents=5, dimC=20, r=10, m=10000, n=50, iters=1000, lr=0.1, verbose=False)
#exp8 = execute(nagents=5, dimC=20, r=50, m=10000, n=50, iters=1000, lr=0.1, verbose=False)
#exp9 = execute(nagents=5, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False)
print(exp7[4], exp8[4], exp9[4])
plt.yscale("log")
index = 0; #history, compute_history, quantize_history, bit_history, comp_ratio
plt.figure(1)
plt.xlabel("Iteration #");
plt.ylabel("Relative Optimality Gap")
plt.title("Optimality gap vs Iteration, dep. on Frequency of Recompute")
plt.plot(range(len(exp7[index])), exp7[index], label="Frq = 10")
plt.plot(range(len(exp8[index])), exp8[index], label="Frq = 50")
plt.plot(range(len(exp9[index])), exp9[index], label="Frq = 100")
plt.plot(range(len(h2)), h2, label='2-bit quantization')
plt.plot(range(len(h1)), h1, label='Full precision baseline')
plt.legend()

index = 1; 
plt.figure(2)
plt.title("Convergence of Recompute, dep. on Frequency")
plt.xlabel("Iteration #");
plt.ylabel("Minimum euclidean distance to true gradient")
t1 = [2*i for i in range(len(exp8[index]))]
t2 = [10*i for i in range(len(exp9[index]))]
plt.plot(range(len(exp7[index])), exp7[index], label="Frq = 10")
plt.plot(t1, exp8[index], label="Frq = 50")
plt.plot(t2, exp9[index], label="Frq = 100")
plt.legend()
# Out:
# 2.031825 0.511775 0.306448087431694

# %%
meta = 'exp1 = execute(nagents=5, dimC=5, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp2 = execute(nagents=5, dimC=10, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp3 = execute(nagents=5, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp4 = execute(nagents=5, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp5 = execute(nagents=10, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp6 = execute(nagents=50, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp7 = execute(nagents=5, dimC=20, r=10, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp8 = execute(nagents=5, dimC=20, r=50, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp9 = execute(nagents=5, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | end'
e = {'1': exp1, '2': exp2, '3': exp3, '4': exp4, '5': exp5, '6': exp6, '7': exp7, '8': exp8, '9': exp9, 'meta':meta}
with open('ellipsoid_06042023.pickle', 'wb') as handle:
    pickle.dump(e, handle, protocol=pickle.HIGHEST_PROTOCOL)
