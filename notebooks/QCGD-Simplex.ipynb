# %%
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp
import pickle
from multiprocessing import Pool
import random
import time

# %%
class Quantizer():
    def __init__(self, iters, dimC):
        self.iters = iters;
        self.C = None;
        self.A = None;
        self.dimC = dimC;
        
    def load(self, grads):
        self.grads = grads;
        self.d = np.shape(grads)[0];
        self.m = np.shape(grads)[1];
        self.betas = np.ones((self.m,));

    def objective(self, C, A):
        #print(np.shape(C), np.shape(A), np.shape(self.grads))
        total = 0;
        for i in range(self.m):
            total += self.betas[i]*np.square(np.linalg.norm(self.grads[:,i] - C@A))/np.square(np.linalg.norm(self.grads[:,i]))
        return total/self.m

    def find(self, u, sv):
        condition = u > ( (sv-1) / range(1,len(u)+1) )
        for i in reversed(range(len(condition))):
            if condition[i]:
                return i

    def projToSmplx(self, v):
        u = np.sort(v)[::-1]
        sv = np.cumsum(u)
        ind = self.find(u,sv)
        theta = (sv[ind]-1) / (ind+1)
        x = np.maximum(v - theta, 0)
        return x
    
    def grad_C(self, C, A):
        g = np.zeros(np.shape(C));
        for i in range(self.m):
            # add = self.betas[i]*np.expand_dims((C@A - self.grads[:,i]),1)@np.expand_dims(A, 1).T
            add = self.betas[i] * np.outer(C@A - self.grads[:,i], A)
            g += add
        return g

    def grad_A(self, C, A, index):
        g = np.zeros(np.shape(A));
        for i in range(self.m):
            add = self.betas[index]*(C.T@(C@A - self.grads[:,i]));
            g += add
        return g
    
    def compute(self, verbose):
        C = np.random.randn(self.d, self.dimC) if self.C is None else self.C
        A = np.ones((self.dimC)) * 1/self.dimC if self.A is None else self.A
        history = 0;
        for iter in range(self.iters):
            c_grad = self.grad_C(C, A);
            obj_value = self.objective(C, A);
            akc = (obj_value + (10/(10+iter)))/np.square(np.linalg.norm(c_grad));
            C = C - akc*c_grad
            a_grad = self.grad_A(C, A, 0);
            aka = (obj_value + (10/(10+iter)))/np.square(np.linalg.norm(a_grad));
            update = A - aka*a_grad
            A = self.projToSmplx(A - aka*a_grad);
        history = obj_value;
        self.C = C
        self.A = A;
        if(verbose):
            plt.plot(range(self.iters), history);
        return history;

    
    def quantize(self, dimC, g):
        dimC = min(dimC, self.dimC);
        a = cp.Variable(dimC);
        objective = cp.Minimize(cp.square(cp.norm(self.C@a - g)));
        constraints = [a >= 0, cp.sum(a) == 1];
        prob = cp.Problem(objective, constraints);
        opt = prob.solve("SCS");
        if(opt == float('inf')):
            a = self.A/sum(self.A);
        else:
            a = np.maximum(a.value, 0)/sum(np.maximum(a.value, 0));
        val = 0;
        index = np.random.choice(np.arange(dimC), p=a);
        return (index, val)

# %%
## Distributed Least Squares Toy Model ##
class AgentLSQ():
    def __init__(self, A, b, nagents, r, dimC, qflag):
        self.A = A
        self.b = b
        self.r = r;
        self.nagents = nagents;
        self.grads = [];
        self.PASS = True;
        iters = 10000;
        self.Q = Quantizer(iters, dimC);
        self.qflag = qflag;
    
    def grad(self, x, flag):
        lmbda = 0.1
        g = self.A.T@self.A@x - self.A.T@self.b + lmbda*2*x
        self.grads.append(np.expand_dims(g, 1));
        ch = -1;
        qh = -1;
        bits = 0;
        if(self.qflag != 0):
            flag = False; # always send full precision gradients if False;
        if(((len(self.grads)-self.r >= 0) or (len(self.grads) >= 2 and self.PASS)) and flag):
            G = np.hstack(self.grads);
            self.Q.load(G);
            start = time.time();
            ch = self.Q.compute(False);
            print("Time to compute C = ", time.time() - start);
            self.grads = [];
            self.PASS = False;
            print("Recomputing C... | Converged with value = ", ch)
            bits += self.Q.dimC*self.Q.d
        if(self.Q.C is not None and flag):
            bits += self.Q.dimC
            ghat, qh = self.Q.quantize(self.Q.C.shape[1], g)
            return (self.Q.C[:,ghat], ch, qh, bits)
        else:
            if(self.qflag == 2):
                g = np.sign(g);
            print("Sending full precision gradients")
            bits += len(g)
            return (g, ch, qh, bits)
        
    def objective(self, x):
        return np.square(np.linalg.norm(self.A@x-self.b)) + np.square(np.linalg.norm(x));
    
class DLSQ():
    def __init__(self, m, n, nagents, lr, r, dimC, qflag):
        A = np.random.random((m,n))
        z = np.random.random((n,))
        b = A@z + np.random.random((m))
        self.r = r;
        lmbda = 0.1
        print('Computing optimal...');
        self.optimal = np.square(np.linalg.norm(A@np.linalg.inv(A.T@A + lmbda*np.identity(n))@A.T@b-b))
        print('finished! | optimal = ', self.optimal)
        
        self.x = np.zeros((n,));
        self.m = m;
        self.n = n;
        self.nagents = nagents;
        self.lr = lr;  
        self.agents = self.distribute(A, b, nagents, r, dimC, qflag);
        
        self.A = A;
        self.b = b;
    
    def split(self, a, n):
        k, m = divmod(len(a), n)
        return (a[i*k+min(i, m):(i+1)*k+min(i+1, m)] for i in range(n))

    def distribute(self, A, b, nagents, r, dimC, qflag):
        agents = [];
        splits = list(self.split(range(self.m), self.nagents))
        
        for sp in splits:
            agents.append(AgentLSQ(A[sp, :], b[sp], self.nagents, r, dimC, qflag));
        return agents;
    
    def computeGradFromLocal(self, x, flag):
        temp = np.zeros((self.n,))
        normalizing = 0;
        total_bits = 0;
        for n in range(self.nagents):
            localgrad, ch, qh, bits = self.agents[n].grad(self.x, flag)
            total_bits += bits;
            temp += localgrad
            normalizing += np.linalg.norm(localgrad)
        return (temp/normalizing, ch, qh, total_bits);
    
    def step(self, i, flag):
        g, ch, qh, bits = self.computeGradFromLocal(self.x, flag);
        ak = (self.objective()-self.optimal)/np.square(np.linalg.norm(g));
        xnext = self.x - min(ak, self.lr/(np.sqrt(i+1)))*g #min(ak, self.lr/(i+1))
        self.x = xnext + 0.01*(xnext - self.x);
        return (ch, qh, bits);
    
    def objective(self):
        return np.sum([self.agents[i].objective(self.x) for i in range(self.nagents)])
        
    def run(self, iters, verbose):
        history = [];
        compute_history = [];
        quantize_history = [];
        bit_history = [];
        i = 0;
        run = True;
        while(run and i < iters):
            print("Current objective value = ", np.square(np.linalg.norm(self.A@self.x - self.b)) + np.square(np.linalg.norm(self.x)))
            gap = (self.objective()-self.optimal)/self.optimal
            print("Iteration = " + str(i) + " | Relative Optimality gap = " + str(gap))
            print("")
            if(np.abs(gap) <= 1e-1):
                run = False;
            history.append(gap);
            
            flag = True
            if(i >= self.r):
                flag = (np.diff(history[-3::], 1, 0) >= 0).all()
                flag = not flag
                
            ch, qh, bits = self.step(i, flag);
            bit_history.append(bits);
            if(ch != -1):
                compute_history.append(ch)
            if(qh != -1):
                quantize_history.append(qh);
            i += 1;
        #if(verbose):
        #    plt.yscale('log')
        #    plt.plot(range(i), history);
        return (history, compute_history, quantize_history, bit_history);

# %%
## Execute DLSQ without Quantization ##
def execute(nagents, dimC, r, m=10, n=100, iters=1000, lr=1.0,verbose=False, qflag=0): 
    dlsqexe = DLSQ(m, n, nagents, lr, r, dimC, qflag);
    history, compute_history, quantize_history, bit_history = dlsqexe.run(iters, True)
    comp_ratio = np.sum(bit_history)/(n*nagents*len(history))
    print("Compression ratio achieved = ", comp_ratio);
    print("Optimal = ", dlsqexe.optimal)
    print("")
    print("Done...")
    print("___________________________________________________________________")
    return history, compute_history, quantize_history, bit_history, comp_ratio

# %%
# No quantization here #
h1, c1, q1, b1, cr1 = execute(nagents=5, dimC=5, r=50, m=10000, n=50, iters=1000, lr=0.1, verbose=False, qflag=1)
h2, c2, q2, b2, cr2 = execute(nagents=5, dimC=5, r=50, m=10000, n=50, iters=1000, lr=0.1, verbose=False, qflag=2)
# Out:
# Computing optimal...
# finished! | optimal =  839.5109735220976
# Current objective value =  1289658.5933379484
# Iteration = 0 | Relative Optimality gap = 1535.2021867651051
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1209811.0735619052
# Iteration = 1 | Relative Optimality gap = 1440.0902924650436
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1154895.257450247
# Iteration = 2 | Relative Optimality gap = 1374.6763315445519
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1111005.7880444375
# Iteration = 3 | Relative Optimality gap = 1322.3966392375967
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1073685.810616619
# Iteration = 4 | Relative Optimality gap = 1277.9423376234176
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1040847.9566044405
# Iteration = 5 | Relative Optimality gap = 1238.8270130126402
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  1011318.2061158901
# Iteration = 6 | Relative Optimality gap = 1203.6522065278732
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  984359.2867065617
# Iteration = 7 | Relative Optimality gap = 1171.53970035118
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  959472.531677534
# Iteration = 8 | Relative Optimality gap = 1141.895496996874
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  936302.1081239383
# Iteration = 9 | Relative Optimality gap = 1114.2957385040786
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  914583.6042836915
# Iteration = 10 | Relative Optimality gap = 1088.425465158489
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  894114.1993940835
# Iteration = 11 | Relative Optimality gap = 1064.0430826797806
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  874734.2843158522
# Iteration = 12 | Relative Optimality gap = 1040.9584692354179
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  856315.5815292202
# Iteration = 13 | Relative Optimality gap = 1019.0188243202359
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  838753.159500374
# Iteration = 14 | Relative Optimality gap = 998.099156498569
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  821959.8867724164
# Iteration = 15 | Relative Optimality gap = 978.0956772762815
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  805862.4725403363
# Iteration = 16 | Relative Optimality gap = 958.9210847471226
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  790398.5720942655
# Iteration = 17 | Relative Optimality gap = 940.501115679671
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  775514.6267914211
# Iteration = 18 | Relative Optimality gap = 922.7719725538111
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  761164.2228741026
# Iteration = 19 | Relative Optimality gap = 905.6783686317619
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  747306.8245123294
# Iteration = 20 | Relative Optimality gap = 889.1720187947737
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  733906.7817970079
# Iteration = 21 | Relative Optimality gap = 873.2104578930193
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  720932.5441038235
# Iteration = 22 | Relative Optimality gap = 857.7561037272044
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  708356.0291439238
# Iteration = 23 | Relative Optimality gap = 842.7755054798262
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  696152.1116251294
# Iteration = 24 | Relative Optimality gap = 828.2387346230627
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  684298.204928331
# Iteration = 25 | Relative Optimality gap = 814.1188866236846
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  672773.9159212707
# Iteration = 26 | Relative Optimality gap = 800.3916697671287
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  661560.7578647755
# Iteration = 27 | Relative Optimality gap = 787.0350631796282
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  650641.9098924132
# Iteration = 28 | Relative Optimality gap = 774.0290303272739
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  640002.0141501209
# Iteration = 29 | Relative Optimality gap = 761.3552773745556
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  629627.0036307239
# Iteration = 30 | Relative Optimality gap = 748.9970481057744
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  619503.955211188
# Iteration = 31 | Relative Optimality gap = 736.9389488672292
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  609620.9635252707
# Iteration = 32 | Relative Optimality gap = 725.1667983279359
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  599967.0321713706
# Iteration = 33 | Relative Optimality gap = 713.6674978895355
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  590531.9794297165
# Iteration = 34 | Relative Optimality gap = 702.4289193793114
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  581306.356191798
# Iteration = 35 | Relative Optimality gap = 691.4398072900805
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  572281.3742227192
# Iteration = 36 | Relative Optimality gap = 680.6896933283648
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  563448.8432096587
# Iteration = 37 | Relative Optimality gap = 670.1688214283208
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  554801.1153160254
# Iteration = 38 | Relative Optimality gap = 659.868081706242
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  546331.0361757461
# Iteration = 39 | Relative Optimality gap = 649.7789520863552
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  538031.9014363955
# Iteration = 40 | Relative Optimality gap = 639.8934465362445
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  529897.4181020928
# Iteration = 41 | Relative Optimality gap = 630.2040690196188
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  521921.67004373524
# Iteration = 42 | Relative Optimality gap = 620.7037724130887
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  514099.0871403139
# Iteration = 43 | Relative Optimality gap = 611.3859217481881
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  506424.41759475635
# Iteration = 44 | Relative Optimality gap = 602.2442612347987
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  498892.7030340577
# Iteration = 45 | Relative Optimality gap = 593.2728846011391
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  491499.25605892413
# Iteration = 46 | Relative Optimality gap = 584.4662083515459
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  484239.6399547054
# Iteration = 47 | Relative Optimality gap = 575.8189475987164
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  477109.650314633
# Iteration = 48 | Relative Optimality gap = 567.3260941738365
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  470105.29835958406
# Iteration = 49 | Relative Optimality gap = 558.9828967575635
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  463222.7957667939
# Iteration = 50 | Relative Optimality gap = 550.7848428084206
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  456458.540843956
# Iteration = 51 | Relative Optimality gap = 542.727642093784
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  449809.1059057107
# Iteration = 52 | Relative Optimality gap = 534.8072116531159
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  443271.2257271333
# Iteration = 53 | Relative Optimality gap = 527.0196620440915
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  436841.7869640073
# Iteration = 54 | Relative Optimality gap = 519.3612847403322
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  430517.81844274985
# Iteration = 55 | Relative Optimality gap = 511.828540565042
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  424296.4822341857
# Iteration = 56 | Relative Optimality gap = 504.4180490583432
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  418175.0654351903
# Iteration = 57 | Relative Optimality gap = 497.12657868780684
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  412150.97259078553
# Iteration = 58 | Relative Optimality gap = 489.95103782186777
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  406221.71869671723
# Iteration = 59 | Relative Optimality gap = 482.88846639469756
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  400384.9227290807
# Iteration = 60 | Relative Optimality gap = 475.9360281988787
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  394638.30165327137
# Iteration = 61 | Relative Optimality gap = 469.09100374903943
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  388979.66486956447
# Iteration = 62 | Relative Optimality gap = 462.3507836655871
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  383406.9090570506
# Iteration = 63 | Relative Optimality gap = 455.7128625329511
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  377918.0133815534
# Iteration = 64 | Relative Optimality gap = 449.1748331913932
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  372511.0350366137
# Iteration = 65 | Relative Optimality gap = 442.7343814255547
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  367184.1050896731
# Iteration = 66 | Relative Optimality gap = 436.38928101654955
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  361935.4246083085
# Iteration = 67 | Relative Optimality gap = 430.1373891276468
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  356763.2610437832
# Iteration = 68 | Relative Optimality gap = 423.9766419964592
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  351665.9448513242
# Iteration = 69 | Relative Optimality gap = 417.9050509091145
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  346641.86632846
# Iteration = 70 | Relative Optimality gap = 411.9206984341751
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  341689.4726544655
# Iteration = 71 | Relative Optimality gap = 406.02173489610897
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  336807.2651154971
# Iteration = 72 | Relative Optimality gap = 400.20637506994984
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  331993.79650137824
# Iteration = 73 | Relative Optimality gap = 394.4728950804239
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  327247.66866123443
# Iteration = 74 | Relative Optimality gap = 388.8196294902905
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  322567.53020628775
# Iteration = 75 | Relative Optimality gap = 383.2449685639781
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  317952.07434912556
# Iteration = 76 | Relative Optimality gap = 377.7473556937836
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  313400.0368696653
# Iteration = 77 | Relative Optimality gap = 372.3252849769863
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  308910.1941988479
# Iteration = 78 | Relative Optimality gap = 366.9772989332
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  304481.36161184177
# Iteration = 79 | Relative Optimality gap = 361.701986352168
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  300112.3915232009
# Iteration = 80 | Relative Optimality gap = 356.4979802630054
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  295802.1718770343
# Iteration = 81 | Relative Optimality gap = 351.3639560166146
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  291549.62462579395
# Iteration = 82 | Relative Optimality gap = 346.29862947366126
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  287353.7042917903
# Iteration = 83 | Relative Optimality gap = 341.3007552910926
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  283213.39660600276
# Iteration = 84 | Relative Optimality gap = 336.36912530072766
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  279127.7172191686
# Iteration = 85 | Relative Optimality gap = 331.5025669739432
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  275095.7104805138
# Iteration = 86 | Relative Optimality gap = 326.6999419669333
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  271116.44827983796
# Iteration = 87 | Relative Optimality gap = 321.96014474143317
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  267189.0289489803
# Iteration = 88 | Relative Optimality gap = 317.28210125617824
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  263312.57621898904
# Iteration = 89 | Relative Optimality gap = 312.6647677247132
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  259486.23822957888
# Iteration = 90 | Relative Optimality gap = 308.10712943548657
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  255709.18658770746
# Iteration = 91 | Relative Optimality gap = 303.60819963045367
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  251980.61547232687
# Iteration = 92 | Relative Optimality gap = 299.16701843868276
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  248299.74078257164
# Iteration = 93 | Relative Optimality gap = 294.7826518617007
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  244665.79932683439
# Iteration = 94 | Relative Optimality gap = 290.45419080754294
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  241078.04805035674
# Iteration = 95 | Relative Optimality gap = 286.1807501706824
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  237535.76329912123
# Iteration = 96 | Relative Optimality gap = 281.96146795519815
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  234038.240117983
# Iteration = 97 | Relative Optimality gap = 277.7955044387303
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  230584.79158111144
# Iteration = 98 | Relative Optimality gap = 273.6820413749215
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  227174.7481529459
# Iteration = 99 | Relative Optimality gap = 269.6202812322047
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  223807.4570779791
# Iteration = 100 | Relative Optimality gap = 265.6094464669321
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  220482.2817977977
# Iteration = 101 | Relative Optimality gap = 261.6487788289695
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  217198.60139390428
# Iteration = 102 | Relative Optimality gap = 257.7375386980021
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  213955.8100549423
# Iteration = 103 | Relative Optimality gap = 253.87500444890807
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  210753.31656702884
# Iteration = 104 | Relative Optimality gap = 250.06047184465797
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  207590.5438259831
# Iteration = 105 | Relative Optimality gap = 246.29325345529486
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  204466.92837031107
# Iteration = 106 | Relative Optimality gap = 242.57267810163904
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  201381.91993387687
# Iteration = 107 | Relative Optimality gap = 238.8980903224433
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  198334.98101725633
# Iteration = 108 | Relative Optimality gap = 235.26884986380108
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  195325.58647682745
# Iteration = 109 | Relative Optimality gap = 231.68433118968358
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  192353.22313070917
# Iteration = 110 | Relative Optimality gap = 228.1439230125443
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  189417.38938071093
# Iteration = 111 | Relative Optimality gap = 224.64702784299726
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  186517.59484950686
# Iteration = 112 | Relative Optimality gap = 221.19306155762814
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  183653.36003228874
# Iteration = 113 | Relative Optimality gap = 217.78145298405468
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  180824.2159622015
# Iteration = 114 | Relative Optimality gap = 214.41164350240146
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  178029.70388889656
# Iteration = 115 | Relative Optimality gap = 211.08308666240342
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  175269.3749695836
# Iteration = 116 | Relative Optimality gap = 207.79524781539428
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  172542.78997198874
# Iteration = 117 | Relative Optimality gap = 204.54760376047938
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  169849.51898866444
# Iteration = 118 | Relative Optimality gap = 201.33964240423035
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  167189.1411621259
# Iteration = 119 | Relative Optimality gap = 198.17086243327418
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  164561.24442031444
# Iteration = 120 | Relative Optimality gap = 195.04077299918615
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  161965.42522192054
# Iteration = 121 | Relative Optimality gap = 191.948893415125
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  159401.28831111809
# Iteration = 122 | Relative Optimality gap = 188.8947528636797
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  156868.44648129
# Iteration = 123 | Relative Optimality gap = 185.87789011542645
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  154366.52034734536
# Iteration = 124 | Relative Optimality gap = 182.8978532577188
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  151895.13812624806
# Iteration = 125 | Relative Optimality gap = 179.95419943326027
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  149453.93542539948
# Iteration = 126 | Relative Optimality gap = 177.04649458803132
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  147042.55503853268
# Iteration = 127 | Relative Optimality gap = 174.17431322816475
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  144660.64674879637
# Iteration = 128 | Relative Optimality gap = 171.3372381853847
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  142307.86713871936
# Iteration = 129 | Relative Optimality gap = 168.53486039064217
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  139983.87940676633
# Iteration = 130 | Relative Optimality gap = 165.7667786556009
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  137688.35319020526
# Iteration = 131 | Relative Optimality gap = 163.0325994616426
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  135420.96439402457
# Iteration = 132 | Relative Optimality gap = 160.3319367560777
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  133181.39502564823
# Iteration = 133 | Relative Optimality gap = 157.66441175526285
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  130969.33303521146
# Iteration = 134 | Relative Optimality gap = 155.02965275434204
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  128784.4721611688
# Iteration = 135 | Relative Optimality gap = 152.42729494333886
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  126626.51178101957
# Iteration = 136 | Relative Optimality gap = 149.85698022934554
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  124495.15676694369
# Iteration = 137 | Relative Optimality gap = 147.31835706456008
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  122390.11734615295
# Iteration = 138 | Relative Optimality gap = 144.81108027994094
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  120311.10896577005
# Iteration = 139 | Relative Optimality gap = 142.33481092425438
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  118257.85216205682
# Iteration = 140 | Relative Optimality gap = 139.88921610830354
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  116230.07243382269
# Iteration = 141 | Relative Optimality gap = 137.4739688541357
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  114227.50011985023
# Iteration = 142 | Relative Optimality gap = 135.08874794903514
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  112249.87028018305
# Iteration = 143 | Relative Optimality gap = 132.73323780411698
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  110296.9225811286
# Iteration = 144 | Relative Optimality gap = 130.40712831734558
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  108368.40118383437
# Iteration = 145 | Relative Optimality gap = 128.11011474080954
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  106464.0546363024
# Iteration = 146 | Relative Optimality gap = 125.84189755209295
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  104583.63576871368
# Iteration = 147 | Relative Optimality gap = 123.6021823295884
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  102726.90159193847
# Iteration = 148 | Relative Optimality gap = 121.39067963160558
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  100893.61319911522
# Iteration = 149 | Relative Optimality gap = 119.20710487913476
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  99083.535670185
# Iteration = 150 | Relative Optimality gap = 117.05117824213096
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  97296.43797927348
# Iteration = 151 | Relative Optimality gap = 114.92262452919017
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  95532.09290481757
# Iteration = 152 | Relative Optimality gap = 112.8211730804945
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  93790.27694233676
# Iteration = 153 | Relative Optimality gap = 110.74655766390826
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  92070.77021975613
# Iteration = 154 | Relative Optimality gap = 108.69851637411281
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  90373.35641518823
# Iteration = 155 | Relative Optimality gap = 106.67679153467081
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  88697.82267708867
# Iteration = 156 | Relative Optimality gap = 104.68112960291782
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  87043.95954670067
# Iteration = 157 | Relative Optimality gap = 102.71128107758044
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  85411.56088270927
# Iteration = 158 | Relative Optimality gap = 100.76700040902672
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  83800.42378802865
# Iteration = 159 | Relative Optimality gap = 98.84804591205706
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  82210.34853864832
# Iteration = 160 | Relative Optimality gap = 96.95417968114796
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  80641.13851446817
# Iteration = 161 | Relative Optimality gap = 95.08516750806456
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  79092.60013205429
# Iteration = 162 | Relative Optimality gap = 93.24077880176159
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  77564.54277925042
# Iteration = 163 | Relative Optimality gap = 91.42078651049403
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  76056.77875158285
# Iteration = 164 | Relative Optimality gap = 89.62496704606465
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  74569.12319039833
# Iteration = 165 | Relative Optimality gap = 87.85310021013561
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  73101.39402267731
# Iteration = 166 | Relative Optimality gap = 86.10496912253562
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  71653.41190246737
# Iteration = 167 | Relative Optimality gap = 84.38036015149707
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  70225.00015388273
# Iteration = 168 | Relative Optimality gap = 82.67906284575906
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  68815.98471561985
# Iteration = 169 | Relative Optimality gap = 81.00086986847523
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  67426.19408693802
# Iteration = 170 | Relative Optimality gap = 79.34557693286804
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  66055.4592750589
# Iteration = 171 | Relative Optimality gap = 77.71298273957223
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  64703.613743938586
# Iteration = 172 | Relative Optimality gap = 76.10288891561362
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  63370.49336436829
# Iteration = 173 | Relative Optimality gap = 74.51509995497052
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  62055.9363653612
# Iteration = 174 | Relative Optimality gap = 72.9494231606669
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  60759.78328678483
# Iteration = 175 | Relative Optimality gap = 71.40566858834968
#
# Sending full precision gradients
# ...
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  993.8050010112613
# Iteration = 943 | Relative Optimality gap = 0.2504976464557336
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  992.8010302031346
# Iteration = 944 | Relative Optimality gap = 0.2493593117203958
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  991.6588171845964
# Iteration = 945 | Relative Optimality gap = 0.2480066759346895
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  990.6617532106335
# Iteration = 946 | Relative Optimality gap = 0.24687513508236258
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  989.5450183228234
# Iteration = 947 | Relative Optimality gap = 0.24555432974231559
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  988.554582116476
# Iteration = 948 | Relative Optimality gap = 0.2444255187544503
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  987.4847440256448
# Iteration = 949 | Relative Optimality gap = 0.24316280538521431
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  986.5082237301294
# Iteration = 950 | Relative Optimality gap = 0.24205082813116
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  985.4452744406823
# Iteration = 951 | Relative Optimality gap = 0.24079632819925914
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  984.4689852381746
# Iteration = 952 | Relative Optimality gap = 0.23967964879732856
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  983.4315426526463
# Iteration = 953 | Relative Optimality gap = 0.2384574980796844
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  982.475173307477
# Iteration = 954 | Relative Optimality gap = 0.2373725734273207
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  981.4150128824034
# Iteration = 955 | Relative Optimality gap = 0.23612025464002395
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  980.4608034124292
# Iteration = 956 | Relative Optimality gap = 0.23502867583782028
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  979.4449249729784
# Iteration = 957 | Relative Optimality gap = 0.23383361224815316
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  978.4977596252609
# Iteration = 958 | Relative Optimality gap = 0.23275204717773115
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  977.4888768164992
# Iteration = 959 | Relative Optimality gap = 0.23156320949089082
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  976.5623349915808
# Iteration = 960 | Relative Optimality gap = 0.23051381974745222
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  975.5462998751716
# Iteration = 961 | Relative Optimality gap = 0.22931419823567695
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  974.6230656695994
# Iteration = 962 | Relative Optimality gap = 0.22825770669147194
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  973.678281335338
# Iteration = 963 | Relative Optimality gap = 0.2271476670262804
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  972.7631373380159
# Iteration = 964 | Relative Optimality gap = 0.22610148199175703
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  971.8272659002691
# Iteration = 965 | Relative Optimality gap = 0.22500091479536055
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  970.9215066085033
# Iteration = 966 | Relative Optimality gap = 0.22396585512860223
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  969.9960481868118
# Iteration = 967 | Relative Optimality gap = 0.2228776687008166
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  969.0996445006323
# Iteration = 968 | Relative Optimality gap = 0.2218536999044313
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  968.1845668398033
# Iteration = 969 | Relative Optimality gap = 0.22077785589478463
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  967.3002513233661
# Iteration = 970 | Relative Optimality gap = 0.2197707721938251
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  966.3588119100069
# Iteration = 971 | Relative Optimality gap = 0.21866238498171892
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  965.484312068836
# Iteration = 972 | Relative Optimality gap = 0.21766794157206495
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  964.5522890351098
# Iteration = 973 | Relative Optimality gap = 0.21657029553793775
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  963.691238895903
# Iteration = 974 | Relative Optimality gap = 0.21559352232725154
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  962.7519344739204
# Iteration = 975 | Relative Optimality gap = 0.21448669454008648
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  961.9001217806077
# Iteration = 976 | Relative Optimality gap = 0.21352086638559528
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  960.9820416529263
# Iteration = 977 | Relative Optimality gap = 0.21243949405049461
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  960.1350089950895
# Iteration = 978 | Relative Optimality gap = 0.21147349778968266
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  959.2845136839064
# Iteration = 979 | Relative Optimality gap = 0.2104772412867059
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  958.4530250914459
# Iteration = 980 | Relative Optimality gap = 0.2095219952990849
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  957.6262199571962
# Iteration = 981 | Relative Optimality gap = 0.20856028288162845
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  956.809127393421
# Iteration = 982 | Relative Optimality gap = 0.20761597728314746
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  955.9921289940247
# Iteration = 983 | Relative Optimality gap = 0.20666749206946539
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  955.1857807612338
# Iteration = 984 | Relative Optimality gap = 0.20573677347224054
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  954.3794736156077
# Iteration = 985 | Relative Optimality gap = 0.20479940976505884
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  953.5822829470859
# Iteration = 986 | Relative Optimality gap = 0.2038811142191311
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  952.7792465023016
# Iteration = 987 | Relative Optimality gap = 0.20294630246926848
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  951.9838569574612
# Iteration = 988 | Relative Optimality gap = 0.2020343518914554
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  951.1950246307142
# Iteration = 989 | Relative Optimality gap = 0.20111299939255764
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  950.4062351495719
# Iteration = 990 | Relative Optimality gap = 0.2002155928510821
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  949.6056798596546
# Iteration = 991 | Relative Optimality gap = 0.19927525689535505
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  948.825614541741
# Iteration = 992 | Relative Optimality gap = 0.1983881920612233
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  948.0346517963476
# Iteration = 993 | Relative Optimality gap = 0.19745926131895536
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  947.265183797738
# Iteration = 994 | Relative Optimality gap = 0.1965866058667378
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  946.4781222554185
# Iteration = 995 | Relative Optimality gap = 0.19566233788805
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  945.7182008253484
# Iteration = 996 | Relative Optimality gap = 0.19479364961645448
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  944.9609796930747
# Iteration = 997 | Relative Optimality gap = 0.19390961654232822
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  944.2093722585241
# Iteration = 998 | Relative Optimality gap = 0.19305222632363553
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Current objective value =  943.4604165383954
# Iteration = 999 | Relative Optimality gap = 0.19217657854603304
#
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Sending full precision gradients
# Compression ratio achieved =  1.0
# Optimal =  844.1605928994154
#
# Done...
# ___________________________________________________________________

# %%
#exp1 = execute(nagents=5, dimC=5, r=50, m=10000, n=50, iters=1000, lr=1.0, verbose=False)
#exp2 = execute(nagents=5, dimC=10, r=50, m=10000, n=50, iters=1000, lr=1.0, verbose=False)
#exp3 = execute(nagents=5, dimC=20, r=50, m=10000, n=50, iters=1000, lr=1.0, verbose=False)
print(exp1[4], exp2[4], exp3[4])
plt.yscale("log")
index = 0; #history, compute_history, quantize_history, bit_history, comp_ratio
plt.figure(1)
plt.xlabel("Iteration #");
plt.ylabel("Relative Optimality Gap")
plt.title("Optimality gap vs Iteration, dep. on M (dimension C)")
plt.plot(range(len(exp1[index])), exp1[index], label="M = 5")
plt.plot(range(len(exp2[index])), exp2[index], label="M = 10")
plt.plot(range(len(exp3[index])), exp3[index], label="M = 20")
plt.plot(range(len(h2)), h2, label='2-bit quantization')
plt.plot(range(len(h1)), h1, label='Full precision baseline')
plt.legend()

index = 1; 
plt.figure(2)
plt.title("Convergence of Recompute, dep. on M (dimension C)")
plt.xlabel("Iteration #");
plt.ylabel("Relative Optimality Gap")
plt.plot(range(len(exp1[index])), exp1[index], label="M = 5")
plt.plot(range(len(exp2[index])), exp2[index], label="M = 10")
plt.plot(range(len(exp3[index])), exp3[index], label="M = 20")
plt.legend()
# Out:
# 0.2576 0.4008 0.8558

# %%
#exp4 = execute(nagents=5, dimC=10, r=100, m=10000, n=50, iters=1000, lr=1.0, verbose=False)
#exp5 = execute(nagents=10, dimC=10, r=100, m=10000, n=50, iters=1000, lr=1.0, verbose=False)
#exp6 = execute(nagents=50, dimC=10, r=100, m=10000, n=50, iters=1000, lr=1.0, verbose=False)
print(exp4[4], exp5[4])
plt.yscale("log")
index = 0; #history, compute_history, quantize_history, bit_history, comp_ratio
plt.figure(1)
plt.xlabel("Iteration #");
plt.ylabel("Relative Optimality Gap")
plt.title("Optimality gap vs Iteration, dep. on # Agents")
plt.plot(range(len(exp4[index])), exp4[index], label="n_agents = 5")
plt.plot(range(len(exp5[index])), exp5[index], label="n_agents = 10")
plt.plot(range(len(h2)), h2, label='2-bit quantization')
plt.plot(range(len(h1)), h1, label='Full precision baseline')
plt.legend()

index = 1; 
plt.figure(2)
plt.title("Convergence of Recompute, dep. on # Agents")
plt.xlabel("Iteration #");
plt.ylabel("Relative Optimality Gap")
plt.plot(range(len(exp4[index])), exp4[index], label="n_agents = 5")
plt.plot(range(len(exp5[index])), exp5[index], label="n_agents = 10")
plt.legend()
# Out:
# 0.3464 0.4016

# %%
#exp7 = execute(nagents=5, dimC=10, r=10, m=10000, n=50, iters=1000, lr=1.0, verbose=False)
#exp8 = execute(nagents=5, dimC=10, r=50, m=10000, n=50, iters=1000, lr=1.0, verbose=False)
#exp9 = execute(nagents=5, dimC=10, r=100, m=10000, n=50, iters=1000, lr=1.0, verbose=False)
print(exp7[4], exp8[4], exp9[4])
plt.yscale("log")
index = 0; #history, compute_history, quantize_history, bit_history, comp_ratio
plt.figure(1)
plt.xlabel("Iteration #");
plt.ylabel("Relative Optimality Gap")
plt.title("Optimality gap vs Iteration, dep. on Frequency of Recompute")
plt.plot(range(len(exp7[index])), exp7[index], label="Frq = 10")
plt.plot(range(len(exp8[index])), exp8[index], label="Frq = 50")
plt.plot(range(len(exp9[index])), exp9[index], label="Frq = 100")
plt.plot(range(len(h2)), h2, label='2-bit quantization')
plt.plot(range(len(h1)), h1, label='Full precision baseline')
plt.legend()

index = 1; 
plt.figure(2)
plt.title("Convergence of Recompute, dep. on Frequency")
plt.xlabel("Iteration #");
plt.ylabel("Relative Optimality Gap")
plt.plot(range(len(exp7[index])), exp7[index], label="Frq = 10")
plt.plot(range(len(exp8[index])), exp8[index], label="Frq = 50")
plt.plot(range(len(exp9[index])), exp9[index], label="Frq = 100")
plt.legend()
# Out:
# 1.2443465491923642 0.4136 0.3328

# %%
meta = 'exp1 = execute(nagents=5, dimC=5, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp2 = execute(nagents=5, dimC=10, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp3 = execute(nagents=5, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp4 = execute(nagents=5, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp5 = execute(nagents=10, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp7 = execute(nagents=5, dimC=20, r=10, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp8 = execute(nagents=5, dimC=20, r=50, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | \
        exp9 = execute(nagents=5, dimC=20, r=100, m=10000, n=50, iters=1000, lr=0.1, verbose=False) | end'
e = {'1': exp1, '2': exp2, '3': exp3, '4': exp4, '5': exp5, '7': exp7, '8': exp8, '9': exp9, 'meta':meta}
with open('simplex_06042023.pickle', 'wb') as handle:
    pickle.dump(e, handle, protocol=pickle.HIGHEST_PROTOCOL)
